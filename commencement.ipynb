# %%
import matplotlib 
import matplotlib.pyplot as plt 
from matplotlib import animation
import numpy as np 


angle = int(input( "Angle initial " ) )
long = int(input( "Longueur de la table " ) )
lim = int(input( "limite de taille du mot" ) )
compteur = 0
n_iter=stratosphérique


class boule :
    def __init__(self):
        self.x = long/2
        self.y = 0
        self.angle = angle
        
coordonnees = []
angles_succ = []
mot_absurde = []

for i in n_iter:

    ## cas de la droite 
    boule.x +=  1   
    boule.y +=  1

    
    
    
    if( boule.x >= long or b.x <=0 ):     (rebond )
        compteur += 1
        boule.angle = 90-boule.angle 
        mot_absurde.append("H")
        ## coordonnées après rebond H :
        
    
        
    if( boule.y >= long or boule.y < 0 ):  
        compteur += 1
        mot_absurde.append("H")
        ## coordonnées après rebond H :
        
    
    
        
        if (compteur = lim) :#2000
            break
    
    
coordonnees.append(boule.x, boule.y)
angles_succ.append(boule.angle)
        
        
        
fig = plt.figure() 
table = plt.axes(xlim=(0, long), ylim=(0, long) ) 

def init():
    boule.set_data([], [])
    return boule,

def parcours(angle, long, fig,i):
    x,y = coordonnes[i]
    boule.set_data(coordonnees[i])
    return boule

anim  = animation.FuncAnimation(fig,parcours,init_func=initialise, blit=True )
# Out:
# Error: Jupyter cannot be started. Error attempting to locate jupyter:
# at A.startServer (c:\Users\AMGHAR MED CHERIF\.vscode\extensions\ms-python.python-2020.2.64397\out\client\extension.js:1:786120)
# at async A.ensureServerAndNotebookImpl (c:\Users\AMGHAR MED CHERIF\.vscode\extensions\ms-python.python-2020.2.64397\out\client\extension.js:1:785575)
# at async A.ensureServerAndNotebook (c:\Users\AMGHAR MED CHERIF\.vscode\extensions\ms-python.python-2020.2.64397\out\client\extension.js:1:785376)
# at async A.submitCode (c:\Users\AMGHAR MED CHERIF\.vscode\extensions\ms-python.python-2020.2.64397\out\client\extension.js:1:782328)
# at async A.reexecuteCell (c:\Users\AMGHAR MED CHERIF\.vscode\extensions\ms-python.python-2020.2.64397\out\client\extension.js:75:879318)
